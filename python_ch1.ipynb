# %%
a=10
b=15                                                                  
print(a-b)
# Out:
# -5

# %%
print(a+b)
# Out:
# 25

# %%
print(a*b)
# Out:
# 150

# %%
print("Division :",a/b)
# Out:
# Division : 0.6666666666666666

# %% [markdown]
# # topic name
# **today we started python in jupyter notebook**

# %%
ca$h=100
# Out:
#   Cell In[5], line 1
#     ca$h=100
#       ^
# SyntaxError: invalid syntax

# %%
1abc=12

# %%
import keyword
print(keyword.kwlist)

print(len(keyword.kwlist))

# %%
finally=15

# %%
__a=10
print (a)
# Out:
# 10

# %%
"abc".isidentifier()
# Out:
# True

# %%
a="Python's Lecture"
print(a)
# Out:
# Python's Lecture

# %%
x=1
y=50502750
z=-4950
print(type(x))
# Out:
# <class 'int'>

# %%
a=0b1111
print(a)
# Out:
# 15

# %%
b=0o1000
print(b)
# Out:
# 512

# %%
c=0x123A
print(c)
# Out:
# 4666

# %%
bin(15)
# Out:
# '0b1111'

# %%
bin(0o11)
# Out:
# '0b1001'

# %%
bin(0x10)
# Out:
# '0b10000'

# %%
A= bin(15)
B= bin(0o11)
print(A,B)
# Out:
# 0b1111 0b1001

# %%
oct(10)
# Out:
# '0o12'

# %%
oct(0b1111)
# Out:
# '0o17'

# %%
oct(0x123)
# Out:
# '0o443'

# %%
hex(100)
# Out:
# '0x64'

# %%
hex(0b11111)
# Out:
# '0x1f'

# %%
hex(0o12345)
# Out:
# '0x14e5'

# %%
a=36e3
print(a)
# Out:
# 36000.0

# %%
l1=[1,2,3,4,5,5,5,4]
l2=['cherry','banana']
l3=[1,2,'cherry']
l4=[True,False,False]
print(type(l1))
# Out:
# <class 'list'>

# %%
print(l2)
print(l3)
print(l4)
# Out:
# ['cherry', 'banana']
# [1, 2, 'cherry']
# [True, False, False]

# %%
a=range(0,10,2)
print(list(a))
# Out:
# [0, 2, 4, 6, 8]

# %%
for i in range(1,11,2):
    print("hello")
    print(i)
# Out:
# hello
# 1
# hello
# 3
# hello
# 5
# hello
# 7
# hello
# 9

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
d={10:"arman",20:"aayan",30:"dhyan",10:"rose"}
print(d)
print(type(d))
print(d[10])
print(d[20])
d[20]="rohit"
print(d)
# Out:
# {10: 'rose', 20: 'aayan', 30: 'dhyan'}
# <class 'dict'>
# rose
# aayan
# {10: 'rose', 20: 'rohit', 30: 'dhyan'}

# %%
s={3,4,2,5,5,6,7,8,4,5,}#mutable
print(s)
print(type(s))
# Out:
# {2, 3, 4, 5, 6, 7, 8}
# <class 'set'>

# %%
x={"apple","banana","cherry"}#order not metter in set
print(x)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
a=frozenset(s)#immutable 
print(a)
print(type(a))
# Out:
# frozenset({2, 3, 4, 5, 6, 7, 8})
# <class 'frozenset'>

# %% [markdown]
# **Boolean Type:bool**

# %%
print(20>8)
print(20==8)
print(20<8)
# Out:
# True
# False
# False

# %%
print(bool("abc"))
print(bool(""))
print(bool(123))
print(bool([1,2,3,4,5]))
print(bool(0))
# Out:
# True
# False
# True
# True
# False

# %%
x=1,2,3,4
print(type(x))#by default data type tuple
#y,e,r,=1,2,3,4 does not accept value because variable and value in not equal no.
#print(y)
# Out:
# <class 'tuple'>

# %% [markdown]
# **local and global variable**

# %%
a="python"
def demo():
    a="java"
    print(a)
demo()
print(a)
# Out:
# java
# python

# %%
a="python"
def demo():
    global a#it is making a to global variable
    a="java"
    print(a)
demo()
print(a)
# Out:
# java
# java

# %%
s=input("Enter data:")
print(s)
print(type(s))
# Out:
# Enter data: 56
# 56
# <class 'str'>

# %%
a=int(input("Enter data:"))
b=int(input("Enter data:"))
print(a+b)
# Out:
# Enter data: 67
# Enter data: 45
# 112

# %% [markdown]
# **Type Casting**

# %%
print(int(123.987))
print(int(True))
print(int(False))
print(int("10"))
#print(int("10.5"))
#print(int("ten"))
#print(int("0b111"))
# Out:
# 123
# 1
# 0
# 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 7
#       4 print(int("10"))
#       5 #print(int("10.5"))
#       6 #print(int("ten"))
# ----> 7 print(int("0b111"))
#
# ValueError: invalid literal for int() with base 10: '0b111'

# %%
print(float(10))
print(float(True))
print(float(False))
print(float("10"))
print(float("10.5"))
print(float("ten"))
print(float("ob111"))
# Out:
# 10.0
# 1.0
# 0.0
# 10.0
# 10.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 6
#       4 print(float("10"))
#       5 print(float("10.5"))
# ----> 6 print(float("ten"))
#       7 print(float("ob111"))
#
# ValueError: could not convert string to float: 'ten'

# %%
print(str(10))
print(str(10.5))
print(str(True))
print(str(False))#all are converted in string
# Out:
# 10
# 10.5
# True
# False

# %%
print(bool(0))
print(bool(1))
print(bool(10.5))
print(bool(0.178))
print(bool(0.0))
print(bool("True"))
print(bool("False"))
# Out:
# False
# True
# True
# True
# False
# True
# True

# %% [markdown]
# # operators

# %% [markdown]
# **arithmetic**

# %%
print("LJ"+"UNI")
print("LJ"*5)
print(18.5//5)
print(18//5)
print(18.5%5)
print(2**5)
#float division gives quotient
#modulo gives remander
#divison always gives ans in float
# Out:
# LJUNI
# LJLJLJLJLJ
# 3.0
# 3
# 3.5
# 32

# %% [markdown]
# **relational operator**

# %%
print(True>5)#because true is 1
print(True>=True)
print(10<20<30>40)
a="armanrujsdjfvsk"#according to ascii value not according to length
b="aryan"
print(a>b)
print(a<b)
print(ord("A"))#ord function gives ascii value
print(ord("$"))
print(chr(36))
print(chr(97))
# Out:
# False
# True
# False
# False
# True
# 65
# 36
# $
# a

# %% [markdown]
# **logical operator**
#
# and-if both are true than only result is true
#
# or-if atleast 1 argument is true then result is true
#
# not-complement

# %%
print(True and False)
print(True and True)
print(True or False)
print(not True)
print(not False)
# Out:
# False
# True
# True
# False
# True

# %% [markdown]
# **Non Boolean**
# and-if X is evaluate to false returns X otherwise return y
#
# or- if X is evalutes to true then result is x otherwise result is y
#
# nor-if Xis evalutes to false then result is true otherwise falsee

# %%
print(10 and 20)# 10(X) is true ans is y
print(0 and 10)#X is false then ans X
print(10 or 20)#X is true ans is X
print(0 or 20)#X is false ans is y
print(not 0)
# Out:
# 20
# 0
# 10
# 20
# True

# %% [markdown]
# **ternary Operator**

# %%
#X - first value if condition else second value 
a=10
b=20
x=30 if a>b else 40
print(x)
# Out:
# 40

# %% [markdown]
# **assignment opretator**

# %%
x=67
print(x)
x+=20
print(x)
x*=5
print(x)
# Out:
# 67
# 87
# 435

# %% [markdown]
# **membership operator**

# %%
x = " python is easy"
print("I" in x)
print("I" not in x)
# Out:
# False
# True

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.pi
math.factorial(5)
math.pow(2,3)
math.ceil(2.5)
math.floor(3)
# Out:
# 8.0

# %%
import matplotlib.pyplot as plt
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %% [markdown]
# ![image.png](attachment:29a59164-5499-46b8-abd5-3f735af23cd7.png)!

# %%
a=30
b=20
c=10
d=5
print((a+b)*(c/d))
print(a+(b*c)/d)
# Out:
# 100.0
# 70.0
